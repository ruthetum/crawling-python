# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthetum/crawling-python/blob/master/icampusCrawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import json

login_url = 'https://icampus.skku.edu/xn-sso/login.php?auto_login=true&sso_only=true&cvs_lgn=&return_url=https%3A%2F%2Ficampus.skku.edu%2Fxn-sso%2Fgw-cb.php%3Ffrom%3Dweb_redirect%26login_type%3Dstandalone%26return_url%3Dhttps%253A%252F%252Ficampus.skku.edu%252Flogin%252Fcallback'
login_check_url = 'https://icampus.skku.edu/xn-sso/customs/pages/logon-url.php'
target_url = 'https://canvas.skku.edu/'

# %%
login_data = dict()
login_data['login_user_id'] = 'r'
login_data['login_user_password'] = '@'

# %%
with requests.session() as s:
    main_req = s.post(login_url)
    html = main_req.text
    obj = BeautifulSoup(html, 'html.parser')
    auth_token = obj.find('input', {'name': 'login_form_token'})['value']
    login_data['login_form_token'] = auth_token

    login_req = s.post(login_check_url, data=login_data)

    if login_req.status_code != 200:
        raise Exception('Log-in Failed')
    
    if (s):
      print(s)
    else:
      print("No")

    result_req = s.post(target_url)

    print(result_req.text)
# Out:
# ...
#
# <!DOCTYPE html>
# <html class="scripts-not-loaded" dir="ltr"   lang="ko">
# <head>
#   <meta charset="utf-8">
#   <title>세션 시간 만료</title>
#   <!--[if lte IE 9]> <meta http-equiv=refresh content="0; URL=/ie-9-is-not-supported.html" /> <![endif]-->
#   <link rel="preload" href="/dist/fonts/lato/latin/LatoLatin-Regular-3cd3657802.woff2" as="font" type="font/woff2" crossorigin>
#   <link rel="shortcut icon" type="image/x-icon" href="https://canvas.skku.edu/accounts/1/files/6/download?verifier=IFheuemxTnuTXf7L4j840s7DfJY0b64qdOLMaeFS" />
#   <link rel="apple-touch-icon" href="https://canvas.skku.edu/accounts/1/files/7/download?verifier=oAfESXWSzbqcemiCg2gyCkhfjZq0Phd3VNMCyiKE" />
#
#   <link rel="stylesheet" media="all" href="/dist/brandable_css/91696a4852c428ae13129692bb170238/variables-750d72b9d3e5d522f965bf904110c132.css" />
#   <link rel="stylesheet" media="all" href="/dist/brandable_css/new_styles_normal_contrast/bundles/common-5f496bd1d1.css" />
#   <script>
# //<![CDATA[
#
# ...
